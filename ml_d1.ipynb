# %% [markdown]
# <a href="https://colab.research.google.com/github/LohithGGowda/no-mercy-ml/blob/main/ml_d1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("lets start")
# Out:
# lets start
